# %%
import pandas as pd
import numpy as pd
from UPIBCF import *

# %%
raw_rating_df = pd.read_csv('new_ratings_all.txt', sep=':', header=None, names=['uid', 'iid', 'rating', 'date', 'comment_type'], dtype={'uid':np.str, 'iid':np.str})

# %%
urdi = UPIBCF.compute_URDI(raw_rating_df)

# %%
uci = UPIBCF.compute_UCI(raw_rating_df)

# %%
upi = UPIBCF.compute_UPI(uci, urdi)

# %%
upi[upi['sum'] > 1000].sort_values('std', ascending=False)
# Out:
#                     UCI   sum         std
# 57507262       0.004038  1981  252.090616
# 33275765       0.002266  1324   89.683480
# 53956912       0.045455  1232   69.384221
# 1069770        0.106755  3035   51.346455
# 125373467      0.417939  1048   50.514369
# 82851721       4.565887  1753   48.528283
# 139123958      0.006166  4217   43.731289
# 46333858       0.262130  1690   41.340843
# mrsbonbon      0.014364  1462   40.464011
# 46643232       0.200463  1726   39.931520
# ohjoo          0.067834  1371   39.635371
# Huxinghang510  0.326483  3017   37.586667
# 3569340        0.013436  1042   34.566661
# lulu.madrid    0.000514  1944   34.458167
# 2238810        0.048340  1717   34.202045
# 51016659       0.446612  1845   28.576700
# 4723556        0.241279  1032   28.450923
# 48671739       0.119883  1026   27.801087
# 63293741       0.405268  1177   27.005095
# 49411879       0.524823  1128   24.276131
# 1514019        0.308634  1552   23.643639
# ...

# %%
RNMUS = UPIBCF.compute_RNMUS(raw_rating_df)

# %%
RNMUS
# Out:
# uid
# 101030945          0.064083
# 101306532          0.009424
# 102009494          0.032866
# 102027189          0.000353
# 10241572           0.113088
# 103402492          0.005183
# 1049890            0.145954
# 104991310          0.011780
# 10564710           0.004948
# 106531709          0.058664
# 1069770            0.357521
# 1079180            0.054188
# 108016742          0.023089
# 109954597          0.004476
# 1111383            0.052067
# 114225619          0.011073
# 114300394          0.041112
# 1145037            0.036400
# 114515320          0.004830
# 114520027          0.049005
# 115608638          0.012016
# 116739424          0.000589
# 119030590          0.059842
# 119591426          0.015314
# 120076971          0.086465
# 120845613          0.077983
# 121362410          0.003770
# 121806653          0.036047
# 122948297          0.013665
# 1230022            0.008835
#                      ...
# xyiyi              0.184474
# yange1991          0.013311
# ...

# %%
IHot = UPIBCF.compute_IHot(raw_rating_df)

# %%
IHot.name = 'hot'

# %%
IHot.index.name = 'hot'

# %%
temp = pd.merge(raw_rating_df, IHot.to_frame(), left_on='iid', right_index=True)

# %%
temp.groupby('uid')

# %%
people = pd.DataFrame(np.random.randn(5, 5), columns=['a', 'b', 'c', 'd', 'e'], index=['joe','steve', 'wes', 'jim', 'travis'])

# %%
people
# Out:
#                a         b         c         d         e
# joe     0.793579 -0.415870  1.344389 -1.024462 -0.815393
# steve   0.505698 -0.875973 -1.168652  0.459257  0.526455
# wes     0.168406  0.629154  1.653655  0.504813 -0.538843
# jim    -0.582171  2.472839 -1.693615  0.620920 -1.414365
# travis -0.833773 -1.062652 -0.082309  0.970275 -0.428879

# %%
key = ['one', 'two', 'one', 'two', 'one']

# %%
people.groupby(key).mean()
# Out:
#             a         b         c         d         e
# one  0.042737 -0.283123  0.971911  0.150209 -0.594372
# two -0.038237  0.798433 -1.431133  0.540088 -0.443955

# %%
def f(df):
    return np.sum(df['rating'] * df['hot'])

# %%
temp.groupby('uid').apply(f)
# Out:
# uid
# 101030945            48084
# 101306532            70022
# 102009494           113375
# 102027189             1369
# 10241572            289169
# 103402492            82575
# 1049890             676995
# 104991310            63027
# 10564710             48796
# 106531709           262081
# 1069770             926812
# 1079180             218524
# 108016742           161391
# 109954597            30260
# 1111383             187235
# 114225619              832
# 114300394           200039
# 1145037             185406
# 114515320            16488
# 114520027           273055
# 115608638            82272
# 116739424             6133
# 119030590           405460
# 119591426           131461
# 120076971           370679
# 120845613           453341
# 121362410            21921
# 121806653           233557
# 122948297            78000
# 1230022              30743
#                     ...
# xyiyi               534365
# yange1991           103623
# yatouzhu             66806
# ...

# %%
a = temp[temp['uid']== '101030945']

# %%
a
# Out:
#            uid       iid  rating        date  comment_type  hot
# 0    101030945  10438426       0  2014-09-29             0  154
# 1    101030945  10455629       0  2014-09-11             0  227
# 2    101030945  10463953       0  2015-07-13             0  396
# 3    101030945  10465145       0  2015-08-22             0   33
# 4    101030945  10467774       0  2016-06-05             0   40
# 5    101030945  10491666       5  2015-06-18             0  149
# 6    101030945  10533913       0  2016-10-23             0  389
# 7    101030945  10535568       0  2016-07-21             0  222
# 8    101030945  10545939       0  2014-10-08             0  208
# 9    101030945  10561953       0  2014-09-30             0  133
# 10   101030945  10574468       0  2014-09-29             0  477
# 11   101030945  10574622       0  2014-09-29             0  508
# 12   101030945  10605978       0  2014-09-29             0  292
# 13   101030945  10741643       0  2015-05-30             0  253
# ...

# %%
np.sum(a['rating'] * a['hot'])
# Out:
# 48084

# %%
import math

# %%
math.log(math.e)
# Out:
# 1.0

# %%
temp
# Out:
#               uid       iid  rating        date  comment_type  hot
# 0       101030945  10438426       0  2014-09-29             0  154
# 908      10241572  10438426       0  2013-06-23             0  154
# 3793      1069770  10438426       4  2013-06-09             0  154
# 6828      1079180  10438426       5  2012-12-04             1  154
# 9277    119030590  10438426       4  2017-03-20             0  154
# 14106   126491753  10438426       3  2016-03-31             0  154
# 14567   127328593  10438426       4  2016-11-03             1  154
# 14970     1287157  10438426       4  2013-03-31             1  154
# 16184   129428484  10438426       3  2017-03-21             0  154
# 28632    14409274  10438426       0  2014-01-18             0  154
# 38958     2010006  10438426       3  2012-11-05             0  154
# 47893     2320102  10438426       3  2012-10-13             1  154
# 50866     2346731  10438426       0  2013-02-18             0  154
# ...

# %%
a
# Out:
#            uid       iid  rating        date  comment_type  hot    b
# 0    101030945  10438426       0  2014-09-29             0  154    0
# 1    101030945  10455629       0  2014-09-11             0  227    0
# 2    101030945  10463953       0  2015-07-13             0  396    0
# 3    101030945  10465145       0  2015-08-22             0   33    0
# 4    101030945  10467774       0  2016-06-05             0   40    0
# 5    101030945  10491666       5  2015-06-18             0  149  745
# 6    101030945  10533913       0  2016-10-23             0  389    0
# 7    101030945  10535568       0  2016-07-21             0  222    0
# 8    101030945  10545939       0  2014-10-08             0  208    0
# 9    101030945  10561953       0  2014-09-30             0  133    0
# 10   101030945  10574468       0  2014-09-29             0  477    0
# 11   101030945  10574622       0  2014-09-29             0  508    0
# 12   101030945  10605978       0  2014-09-29             0  292    0
# ...

# %%
a['hot'] = np.log(a['hot'] - 1 + math.e)
# Out:
# C:\Users\rico\Miniconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
a
# Out:
#            uid       iid  rating        date  comment_type       hot    b
# 0    101030945  10438426       0  2014-09-29             0  5.048048    0
# 1    101030945  10455629       0  2014-09-11             0  5.432491    0
# 2    101030945  10463953       0  2015-07-13             0  5.985744    0
# 3    101030945  10465145       0  2015-08-22             0  3.547266    0
# 4    101030945  10467774       0  2016-06-05             0  3.730939    0
# 5    101030945  10491666       5  2015-06-18             0  5.015412  745
# 6    101030945  10533913       0  2016-10-23             0  5.967987    0
# 7    101030945  10535568       0  2016-07-21             0  5.410388    0
# 8    101030945  10545939       0  2014-10-08             0  5.345765    0
# 9    101030945  10561953       0  2014-09-30             0  4.903186    0
# 10   101030945  10574468       0  2014-09-29             0  6.171112    0
# 11   101030945  10574622       0  2014-09-29             0  6.233858    0
# ...

# %%
np.sum(a['hot'])
# Out:
# 2703.3637721690407

# %%
np.sum(a['comment_type'] * a['hot']) / np.sum(1 / a['hot'])
# Out:
# 0.2314262200875799

# %%
a[a['comment_type'] == 2]
# Out:
# Empty DataFrame
# Columns: [uid, iid, rating, date, comment_type, hot, b]
# Index: []

# %%
np.sum(1 / a['hot'])
# Out:
# 116.34715350128494

# %%
 def f(df):
        df['hot'] = np.log(math.e + df['hot'] - 1)
        return np.sum(df['comment_type'] * df['hot']) / np.sum(1 / df['hot'])

# %%
c = temp.groupby('uid').apply(f)

# %%
pd.concat([RNMUS, c], axis=1)
# Out:
#                         0          1
# uid
# 101030945        0.064083   0.231426
# 101306532        0.009424   4.465745
# 102009494        0.032866   0.161701
# 102027189        0.000353   4.679033
# 10241572         0.113088   6.457879
# 103402492        0.005183   2.964085
# 1049890          0.145954   0.159667
# 104991310        0.011780  18.197803
# 10564710         0.004948   8.267350
# 106531709        0.058664   0.000000
# 1069770          0.357521   1.264533
# 1079180          0.054188   4.297900
# 108016742        0.023089   6.131920
# 109954597        0.004476  18.477283
# 1111383          0.052067   0.865124
# 114225619        0.011073   0.000000
# 114300394        0.041112   3.212953
# 1145037          0.036400   4.296193
# 114515320        0.004830   8.259369
# 114520027        0.049005   1.670920
# 115608638        0.012016   1.899141
# 116739424        0.000589  27.446702
# 119030590        0.059842   0.053278
# 119591426        0.015314   0.650992
# ...
